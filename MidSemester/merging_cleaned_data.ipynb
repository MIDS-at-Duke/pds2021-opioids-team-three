# %% [markdown]
# ### Merging data **by Larissa**
# Here we will merge the following cleaned datasets:
# - prescription from Florida, Kentucky, North Carolina, Georgia
# - death data from all states
# - census data from all states
#
# ---

# %% [markdown]
# importing a csv with states and state abbreviations to change the states to abbrevations in all datasets

# %%
import pandas as pd
df_states = pd.read_csv('USA_States.csv', encoding = "utf-8")

# %% [markdown]
# Import first dataset containing prescription data

# %%
import pandas as pd
df_prescriptions = pd.read_csv('https://raw.githubusercontent.com/MIDS-at-Duke/pds2021-opioids-team-three/main/20_intermediate/prescriptions?token=AI3GZDZGWG25Z2T5V2RXQGDBRO3WS', index_col=0, encoding='utf-8')
df_prescriptions.head()
# Out:
#   BUYER_COUNTY  T_DATE           MME    State
# 0      ALACHUA    2006  1.645948e+12  Florida
# 1      ALACHUA    2007  1.972812e+12  Florida
# 2      ALACHUA    2008  2.540522e+12  Florida
# 3      ALACHUA    2009  3.180395e+12  Florida
# 4      ALACHUA    2010  3.293852e+12  Florida

# %% [markdown]
# Renaming the column T_DATE to have it homogenous in all data sets

# %%
df_prescriptions = df_prescriptions.rename({'T_DATE': 'Year', 'BUYER_COUNTY': 'County'}, axis = 1)

# %% [markdown]
# Changing the values in County to be capitalized and lowercase to be the same as in the other dataframes:

# %%
df_prescriptions['County'] = df_prescriptions['County'].str.lower()
df_prescriptions['County'] = df_prescriptions['County'].str.capitalize()
df_prescriptions.head()
# Out:
#     County  Year           MME    State
# 0  Alachua  2006  1.645948e+12  Florida
# 1  Alachua  2007  1.972812e+12  Florida
# 2  Alachua  2008  2.540522e+12  Florida
# 3  Alachua  2009  3.180395e+12  Florida
# 4  Alachua  2010  3.293852e+12  Florida

# %% [markdown]
# Checking missing data

# %%
df_prescriptions.isna().sum()
# Out:
# County    0
# Year      0
# MME       0
# State     0
# dtype: int64

# %% [markdown]
# Checking how many states this data frame has

# %%
df_prescriptions['State'].unique()
# Out:
# array(['Florida', 'Georgia', 'North Carolina', 'Kentucky'], dtype=object)

# %% [markdown]
# Adding a state abbreviation column by merging

# %%
df_prescriptions_state = pd.merge(df_prescriptions, df_states, on = 'State', how = 'left' , indicator = True)
df_prescriptions_state.sample(20)
# Out:
#         County  Year           MME           State State Abbr _merge
# 393     Nassau  2006  1.970304e+11         Florida         FL   both
# 2010      Ashe  2011  3.475653e+10  North Carolina         NC   both
# 741      Burke  2009  5.240969e+09         Georgia         GA   both
# 1581    Pierce  2009  9.016222e+09         Georgia         GA   both
# 880       Cobb  2013  1.243140e+13         Georgia         GA   both
# 1563     Peach  2009  9.395891e+09         Georgia         GA   both
# 1276    Jasper  2010  4.704177e+09         Georgia         GA   both
# 2716     Surry  2006  4.561057e+11  North Carolina         NC   both
# 1171  Gwinnett  2013  1.003030e+13         Georgia         GA   both
# 2709    Stokes  2008  6.340196e+10  North Carolina         NC   both
# 881       Cobb  2014  1.038558e+13         Georgia         GA   both
# 2978   Bullitt  2007  8.895842e+10        Kentucky         KY   both
# 294       Lake  2006  1.623708e+12         Florida         FL   both
# 2843    Yancey  2007  2.393789e+10  North Carolina         NC   both
# 1785    Toombs  2013  6.738791e+10         Georgia         GA   both
# 3395      Knox  2010  7.881142e+10        Kentucky         KY   both
# 2819    Wilkes  2010  4.973910e+11  North Carolina         NC   both
# 3841   Trimble  2006  1.748955e+08        Kentucky         KY   both
# 3454     Lewis  2006  6.760192e+09        Kentucky         KY   both
# 3034   Carroll  2009  1.441817e+10        Kentucky         KY   both

# %% [markdown]
# Checking merge

# %%
df_prescriptions_state[df_prescriptions_state._merge != "both"]
# Out:
# Empty DataFrame
# Columns: [County, Year, MME, State, State Abbr, _merge]
# Index: []

# %%
df_prescriptions_state = df_prescriptions_state.drop('_merge', axis = 1)

# %%
df_prescriptions_state.head()
# Out:
#     County  Year           MME    State State Abbr
# 0  Alachua  2006  1.645948e+12  Florida         FL
# 1  Alachua  2007  1.972812e+12  Florida         FL
# 2  Alachua  2008  2.540522e+12  Florida         FL
# 3  Alachua  2009  3.180395e+12  Florida         FL
# 4  Alachua  2010  3.293852e+12  Florida         FL

# %% [markdown]
# Importing thr second dataset containing the death data

# %%
df_deaths = pd.read_csv('https://raw.githubusercontent.com/MIDS-at-Duke/pds2021-opioids-team-three/main/20_intermediate_files/deaths.csv?token=AI3GZD6NJFVWRHJMICW5FSTBRO4Z2')
df_deaths['State'] = df_deaths['State'].str.replace(' ','')
df_deaths.head()
# Out:
#           County  County Code    Year Deaths State
# 0  Acadia Parish      22001.0  2003.0   11.0    LA
# 1  Acadia Parish      22001.0  2005.0   23.0    LA
# 2  Acadia Parish      22001.0  2006.0   19.0    LA
# 3  Acadia Parish      22001.0  2007.0   19.0    LA
# 4  Acadia Parish      22001.0  2009.0   11.0    LA

# %% [markdown]
# Displaying all states in the data

# %%
df_deaths['State'].unique()
# Out:
# array(['LA', 'ID', 'CO', 'IL', 'OH', 'PA', 'SC', 'FL', 'NC', 'CA', 'NY',
#        'VA', 'MI', 'MD', 'IN', 'AK', 'TN', 'TX', 'ME', 'MN', 'NJ', 'AL',
#        'MA', 'GA', 'KY', 'NH', 'AR', 'WA', 'WV', 'NM', 'MO', 'RI', 'WI',
#        'OK', 'KS', 'UT', 'NV', 'MT', 'ND', 'VT', 'OR', 'AZ', 'MS', 'DC',
#        'NE', 'CT', 'WY', 'HI', 'IA', 'DE', 'SD'], dtype=object)

# %% [markdown]
# Changing the datatype of Year from float to int to have the same data format for Year in all dataframes

# %%
df_deaths["Year"]= df_deaths["Year"].astype('int64')
df_deaths.head()
# Out:
#           County  County Code  Year Deaths State
# 0  Acadia Parish      22001.0  2003   11.0    LA
# 1  Acadia Parish      22001.0  2005   23.0    LA
# 2  Acadia Parish      22001.0  2006   19.0    LA
# 3  Acadia Parish      22001.0  2007   19.0    LA
# 4  Acadia Parish      22001.0  2009   11.0    LA

# %%
df_deaths_state = pd.merge(df_deaths, df_states, left_on = 'State', right_on = 'State Abbr', how = 'left', indicator= True)
df_deaths_state.sample(20)
# Out:
#                      County  County Code  Year   Deaths State_x  \
# 6047      Rockingham County      33015.0  2011     35.0      NH
# 6185  San Bernardino County       6071.0  2009    227.0      CA
# 5683    Pottawatomie County      40125.0  2008     11.0      OK
# 5608        Plymouth County      25023.0  2003     48.0      MA
# 7113        Trumbull County      39155.0  2010     45.0      OH
# 4606       Middlesex County      25017.0  2015  2992428      MA
# 4309           Marin County       6041.0  2010     28.0      CA
# 7025        Tazewell County      51185.0  2003     14.0      VA
# 5023       New Haven County       9009.0  2003     80.0      CT
# 98           Allegan County      26005.0  2007     17.0      MI
# 2645          Greene County      29077.0  2012     40.0      MO
# 1586        Columbus County      37047.0  2005     11.0      NC
# 5077          Newton County      13217.0  2015       12      GA
# 3789            Lake County      17097.0  2014     65.0      IL
# 6436        Sedgwick County      20173.0  2007     51.0      KS
# 4492       Mendocino County       6045.0  2009     12.0      CA
# 1531        Coconino County       4005.0  2003     11.0      AZ
# 2561         Genesee County      26049.0  2014     96.0      MI
# 1317          Citrus County      12017.0  2008     25.0      FL
# 1647         Cowlitz County      53015.0  2011     27.0      WA
#
#              State_y State Abbr _merge
# 6047   New Hampshire         NH   both
# 6185      California         CA   both
# 5683        Oklahoma         OK   both
# 5608   Massachusetts         MA   both
# 7113            Ohio         OH   both
# 4606   Massachusetts         MA   both
# 4309      California         CA   both
# 7025        Virginia         VA   both
# 5023     Connecticut         CT   both
# 98          Michigan         MI   both
# 2645        Missouri         MO   both
# 1586  North Carolina         NC   both
# 5077         Georgia         GA   both
# 3789        Illinois         IL   both
# 6436          Kansas         KS   both
# 4492      California         CA   both
# 1531         Arizona         AZ   both
# 2561        Michigan         MI   both
# 1317         Florida         FL   both
# 1647      Washington         WA   both

# %% [markdown]
# Checking merge

# %%
df_deaths_state[df_deaths_state._merge != "both"]
# Out:
#                     County  County Code  Year Deaths State_x State_y  \
# 1964  District of Columbia      11001.0  2003  106.0      DC     NaN
# 1965  District of Columbia      11001.0  2004  102.0      DC     NaN
# 1966  District of Columbia      11001.0  2005   87.0      DC     NaN
# 1967  District of Columbia      11001.0  2006  113.0      DC     NaN
# 1968  District of Columbia      11001.0  2007   90.0      DC     NaN
# 1969  District of Columbia      11001.0  2008   69.0      DC     NaN
# 1970  District of Columbia      11001.0  2009   56.0      DC     NaN
# 1971  District of Columbia      11001.0  2010   83.0      DC     NaN
# 1972  District of Columbia      11001.0  2011   79.0      DC     NaN
# 1973  District of Columbia      11001.0  2012   71.0      DC     NaN
# 1974  District of Columbia      11001.0  2013  112.0      DC     NaN
# 1975  District of Columbia      11001.0  2014   90.0      DC     NaN
# 1976  District of Columbia      11001.0  2015    114      DC     NaN
#
#      State Abbr     _merge
# 1964        NaN  left_only
# 1965        NaN  left_only
# 1966        NaN  left_only
# 1967        NaN  left_only
# 1968        NaN  left_only
# 1969        NaN  left_only
# 1970        NaN  left_only
# 1971        NaN  left_only
# 1972        NaN  left_only
# 1973        NaN  left_only
# 1974        NaN  left_only
# 1975        NaN  left_only
# 1976        NaN  left_only

# %%
df_deaths_state =df_deaths_state.drop('State_x', axis = 1)
df_deaths_state =df_deaths_state.drop('_merge', axis = 1)
df_deaths_state = df_deaths_state.rename(columns={'State_y': 'State'})

# %%
df_deaths_state.head()
# Out:
#           County  County Code  Year Deaths      State State Abbr
# 0  Acadia Parish      22001.0  2003   11.0  Louisiana         LA
# 1  Acadia Parish      22001.0  2005   23.0  Louisiana         LA
# 2  Acadia Parish      22001.0  2006   19.0  Louisiana         LA
# 3  Acadia Parish      22001.0  2007   19.0  Louisiana         LA
# 4  Acadia Parish      22001.0  2009   11.0  Louisiana         LA

# %% [markdown]
# Checking missing data

# %%
df_deaths_state.isna().sum()
# Out:
# County          0
# County Code     0
# Year            0
# Deaths          0
# State          13
# State Abbr     13
# dtype: int64

# %% [markdown]
# Importing the third datasset containing census data

# %%
df_census = pd.read_csv('https://raw.githubusercontent.com/MIDS-at-Duke/pds2021-opioids-team-three/main/MidSemester/20_intermediates/CountyPopulations.csv?token=AI3GZD36R6FVBM277DEVPB3BRRDSC', index_col= 0)
df_census.head()
# Out:
#      State          County  Year  Population
# 0  Alabama  Autauga County  2006     49105.0
# 1  Alabama  Baldwin County  2006    168516.0
# 2  Alabama  Barbour County  2006     29556.0
# 3  Alabama     Bibb County  2006     21285.0
# 4  Alabama   Blount County  2006     55978.0

# %% [markdown]
# We are dropping Bedfort City county because it changed from being an independant city to being a town within a county in 2011.

# %%
df_cenus = df_census.drop(df_census[df_census.County == 'Beldford city'].index)

# %%
df_census['State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype=object)

# %%
df_census_state = pd.merge(df_census, df_states, on = 'State', how = 'left' , indicator = True)
df_census_state.head()
# Out:
#      State          County  Year  Population State Abbr _merge
# 0  Alabama  Autauga County  2006     49105.0         AL   both
# 1  Alabama  Baldwin County  2006    168516.0         AL   both
# 2  Alabama  Barbour County  2006     29556.0         AL   both
# 3  Alabama     Bibb County  2006     21285.0         AL   both
# 4  Alabama   Blount County  2006     55978.0         AL   both

# %% [markdown]
# Checking missing data

# %%
df_census_state.isna().sum()
# Out:
# State         0
# County        0
# Year          0
# Population    6
# State Abbr    0
# _merge        0
# dtype: int64

# %%
df_census[df_census.isnull().any(axis = 1)]
# Out:
#           State        County  Year  Population
# 15483  Virginia  Bedford city  2010         NaN
# 18625  Virginia  Bedford city  2011         NaN
# 21767  Virginia  Bedford city  2012         NaN
# 24909  Virginia  Bedford city  2013         NaN
# 28051  Virginia  Bedford city  2014         NaN
# 31193  Virginia  Bedford city  2015         NaN

# %% [markdown]
# Checking merge

# %%
df_census_state[df_census_state._merge != 'both']
# Out:
# Empty DataFrame
# Columns: [State, County, Year, Population, State Abbr, _merge]
# Index: []

# %%
df_census_state =df_census_state.drop('_merge', axis = 1)

# %% [markdown]
# Print original dataframe row numbers

# %%
print(df_prescriptions.shape[0],  'Number of rows for Prescription data')
print(df_deaths.shape[0], 'Number of rows for death data')
print(df_census.shape[0], 'Number of rows for census data')
# Out:
# 3922 Number of rows for Prescription data
# 7925 Number of rows for death data
# 31420 Number of rows for census data

# %% [markdown]
# Print merged dataframe sums

# %%
print(df_prescriptions_state.shape[0],  'Number of rows for Prescription data')
print(df_deaths_state.shape[0], 'Number of rows for death data')
print(df_census_state.shape[0], 'Number of rows for census data')
# Out:
# 3922 Number of rows for Prescription data
# 7925 Number of rows for death data
# 31420 Number of rows for census data

# %% [markdown]
# ### Next step merging
# We want to merged dataframes in the end, hence we merge:
# - prescriptiption data with census
# - death data with census
#
# ---

# %% [markdown]
# First merge of prescription and census

# %%
df_presc_cens = pd.merge(df_prescriptions, df_census, on=['County', 'Year', 'State'],
                                  how='left', validate = 'one_to_one', indicator= 'Merge_value')

# %% [markdown]
# Looking at the merged data, and the missing data.

# %%
df_presc_cens.head()
# Out:
#     County  Year           MME    State  Population Merge_value
# 0  Alachua  2006  1.645948e+12  Florida         NaN   left_only
# 1  Alachua  2007  1.972812e+12  Florida         NaN   left_only
# 2  Alachua  2008  2.540522e+12  Florida         NaN   left_only
# 3  Alachua  2009  3.180395e+12  Florida         NaN   left_only
# 4  Alachua  2010  3.293852e+12  Florida         NaN   left_only

# %%
df_presc_cens.isna().sum()
# Out:
# County            0
# Year              0
# MME               0
# State             0
# Population     3922
# Merge_value       0
# dtype: int64

# %%
df_presc_cens.describe()
# Out:
#               Year           MME  Population
# count  3922.000000  3.922000e+03         0.0
# mean   2009.996430  2.347498e+12         NaN
# std       2.584455  1.662164e+13         NaN
# min    2006.000000  3.027000e+02         NaN
# 25%    2008.000000  7.003393e+09         NaN
# 50%    2010.000000  4.510575e+10         NaN
# 75%    2012.000000  3.389654e+11         NaN
# max    2014.000000  4.258041e+14         NaN

# %%
df_presc_cens[df_presc_cens.Merge_value != 'left_only']
# Out:
# Empty DataFrame
# Columns: [County, Year, MME, State, Population, Merge_value]
# Index: []

# %%
df_presc_cens = df_presc_cens.drop('Merge_value', axis = 1)

# %%
df_presc_cens.head()
# Out:
#     County  Year           MME    State  Population
# 0  Alachua  2006  1.645948e+12  Florida         NaN
# 1  Alachua  2007  1.972812e+12  Florida         NaN
# 2  Alachua  2008  2.540522e+12  Florida         NaN
# 3  Alachua  2009  3.180395e+12  Florida         NaN
# 4  Alachua  2010  3.293852e+12  Florida         NaN

# %% [markdown]
# ### Merging the death data with census data

# %%
df_death_cens = pd.merge(df_deaths_state, df_census_state, on=['County', 'Year', 'State'],
                                  how='inner', validate = 'one_to_one', indicator= 'Merge_Check')

# %%
df_death_cens.head()
# Out:
#           County  County Code  Year Deaths      State State Abbr_x  \
# 0  Acadia Parish      22001.0  2006   19.0  Louisiana           LA
# 1  Acadia Parish      22001.0  2007   19.0  Louisiana           LA
# 2  Acadia Parish      22001.0  2009   11.0  Louisiana           LA
# 3  Acadia Parish      22001.0  2010   13.0  Louisiana           LA
# 4  Acadia Parish      22001.0  2011   10.0  Louisiana           LA
#
#    Population State Abbr_y Merge_Check
# 0     59585.0           LA        both
# 1     59715.0           LA        both
# 2     60095.0           LA        both
# 3     61773.0           LA        both
# 4     61763.0           LA        both

# %%
df_death_cens.isna().sum()
# Out:
# County          0
# County Code     0
# Year            0
# Deaths          0
# State           0
# State Abbr_x    0
# Population      1
# State Abbr_y    0
# Merge_Check     0
# dtype: int64

# %%
df_death_cens[df_death_cens.Merge_Check != 'both']
# Out:
# Empty DataFrame
# Columns: [County, County Code, Year, Deaths, State, State Abbr_x, Population, State Abbr_y, Merge_Check]
# Index: []

# %%
df_death_cens = df_death_cens.drop('Merge_Check', axis = 1)

# %%
print(df_presc_cens.shape[0], 'Number of rows for prescription merged with census data')
print(df_death_cens.shape[0], 'Number of rows for death merged with census data')
# Out:
# 3922 Number of rows for prescription merged with census data
# 6538 Number of rows for death merged with census data

# %%
df_death_cens.head()
# Out:
#           County  County Code  Year Deaths      State State Abbr_x  \
# 0  Acadia Parish      22001.0  2006   19.0  Louisiana           LA
# 1  Acadia Parish      22001.0  2007   19.0  Louisiana           LA
# 2  Acadia Parish      22001.0  2009   11.0  Louisiana           LA
# 3  Acadia Parish      22001.0  2010   13.0  Louisiana           LA
# 4  Acadia Parish      22001.0  2011   10.0  Louisiana           LA
#
#    Population State Abbr_y
# 0     59585.0           LA
# 1     59715.0           LA
# 2     60095.0           LA
# 3     61773.0           LA
# 4     61763.0           LA

# %% [markdown]
# Creating a csv file in case we need that

# %%
pd.DataFrame.to_csv(df_presc_cens, 'merged_presc_cens_data.csv', sep=',', na_rep='.', index=False)

# %%
pd.DataFrame.to_csv(df_death_cens, 'merged_death_cens_data.csv', sep=',', na_rep='.', index=False)
